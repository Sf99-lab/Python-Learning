# %% [markdown]
# <a href="https://colab.research.google.com/github/Sf99-lab/Python-Learning/blob/main/Week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Week 5 Task**
#
# This task will not be graded. You are required to practice the material presented on slides yourself as part of this lab task.

# %% [markdown]
# ## **Series**
# Do the tasks for the series in the code cell following this cell.

# %%
import pandas as pd
grades = pd.Series([87, 100, 91])
grades
# Out:
# 0     87
# 1    100
# 2     91
# dtype: int64

# %%
pd.Series(99.9, range(4))
# Out:
# 0    99.9
# 1    99.9
# 2    99.9
# 3    99.9
# dtype: float64

# %%
pd.Series([87,100,91])
grades[0]
# Out:
# 87

# %%
print("Total Grades: ", grades.count())
print("Mean of Grades: ", grades.mean())
print("Minimum Grades: ", grades.min())
print("Maximum Grade: ", grades.max())
print("Standard deviation of Grades: ", grades.std())
# Out:
# Total Grades:  3
# Mean of Grades:  92.66666666666667
# Minimum Grades:  87
# Maximum Grade:  100
# Standard deviation of Grades:  6.658328118479393

# %%
grades.describe()
# Out:
# count      3.000000
# mean      92.666667
# std        6.658328
# min       87.000000
# 25%       89.000000
# 50%       91.000000
# 75%       95.500000
# max      100.000000
# dtype: float64

# %%
grades = pd.Series([87, 100, 91], index=['Ali', 'Ahmad', 'Rashid'])
grades
# Out:
# Ali        87
# Ahmad     100
# Rashid     91
# dtype: int64

# %%
grades = pd.Series({'Ali': 87, 'Ahmad':100, 'Rashid': 91})
grades
# Out:
# Ali        87
# Ahmad     100
# Rashid     91
# dtype: int64

# %%
grades['Ali']
# Out:
# 87

# %%
grades.Ahmad
# Out:
# 100

# %%
grades.dtypes
# Out:
# dtype('int64')

# %%
grades = pd.Series(['Ali', 'Ahmad', 'Rashid'])
grades.str.contains('a')
# Out:
# 0    False
# 1     True
# 2     True
# dtype: bool

# %%
grades.str.upper()
# Out:
# 0       ALI
# 1     AHMAD
# 2    RASHID
# dtype: object

# %% [markdown]
# # **DataFrames**
#
# Do the tasks for a dataframe discussed in the slides in the code cell following this cell.

# %%
dict = {'Ali': [70, 90, 85], 'Ahmad':[80, 85,90], 'Rashid':[75, 85, 90]}
grades = pd.DataFrame(dict)
grades
# Out:
#    Ali  Ahmad  Rashid
# 0   70     80      75
# 1   90     85      85
# 2   85     90      90

# %%
dict = {'Ali': [70, 90, 85], 'Ahmad':[80, 85,90], 'Rashid':[75, 85, 90]}
grades = pd.DataFrame(dict, index = ['Test1', 'Test2', 'Test3' ])
grades
# Out:
#        Ali  Ahmad  Rashid
# Test1   70     80      75
# Test2   90     85      85
# Test3   85     90      90

# %%
grades['Ali']
# Out:
# Test1    70
# Test2    90
# Test3    85
# Name: Ali, dtype: int64

# %%
grades.Ahmad
# Out:
# Test1    80
# Test2    85
# Test3    90
# Name: Ahmad, dtype: int64

# %%
grades.loc['Test1']
# Out:
# Ali       70
# Ahmad     80
# Rashid    75
# Name: Test1, dtype: int64

# %%
grades.iloc[1]
# Out:
# Ali       90
# Ahmad     85
# Rashid    85
# Name: Test2, dtype: int64

# %%
grades.loc['Test1': 'Test3']
# Out:
#        Ali  Ahmad  Rashid
# Test1   70     80      75
# Test2   90     85      85
# Test3   85     90      90

# %%
grades.iloc[0:2]
# Out:
#        Ali  Ahmad  Rashid
# Test1   70     80      75
# Test2   90     85      85

# %%
grades.loc[['Test1', 'Test3']]
# Out:
#        Ali  Ahmad  Rashid
# Test1   70     80      75
# Test3   85     90      90

# %%
grades.iloc[[0,2]]
# Out:
#        Ali  Ahmad  Rashid
# Test1   70     80      75
# Test3   85     90      90

# %%
grades.loc[['Test1', 'Test3'], ['Ali', 'Rashid']]
# Out:
#        Ali  Rashid
# Test1   70      75
# Test3   85      90

# %%
grades.iloc[[0,2],[0,2]]
# Out:
#        Ali  Rashid
# Test1   70      75
# Test3   85      90

# %%
grades.at['Test2', 'Rashid']
# Out:
# 85

# %%
grades.iat[1,2]
# Out:
# 85

# %%
grades.describe()
# Out:
#              Ali  Ahmad     Rashid
# count   3.000000    3.0   3.000000
# mean   81.666667   85.0  83.333333
# std    10.408330    5.0   7.637626
# min    70.000000   80.0  75.000000
# 25%    77.500000   82.5  80.000000
# 50%    85.000000   85.0  85.000000
# 75%    87.500000   87.5  87.500000
# max    90.000000   90.0  90.000000

# %%
pd.set_option('display.precision', 2)
grades.describe()
# Out:
#          Ali  Ahmad  Rashid
# count   3.00    3.0    3.00
# mean   81.67   85.0   83.33
# std    10.41    5.0    7.64
# min    70.00   80.0   75.00
# 25%    77.50   82.5   80.00
# 50%    85.00   85.0   85.00
# 75%    87.50   87.5   87.50
# max    90.00   90.0   90.00

# %%
grades.T
# Out:
#         Test1  Test2  Test3
# Ali        70     90     85
# Ahmad      80     85     90
# Rashid     75     85     90

# %%
grades.T.describe()
# Out:
#        Test1  Test2  Test3
# count    3.0   3.00   3.00
# mean    75.0  86.67  88.33
# std      5.0   2.89   2.89
# min     70.0  85.00  85.00
# 25%     72.5  85.00  87.50
# 50%     75.0  85.00  90.00
# 75%     77.5  87.50  90.00
# max     80.0  90.00  90.00

# %%
grades.sort_index(ascending = False)
# Out:
#        Ali  Ahmad  Rashid
# Test3   85     90      90
# Test2   90     85      85
# Test1   70     80      75

# %%
grades.sort_index(axis = 1)
# Out:
#        Ahmad  Ali  Rashid
# Test1     80   70      75
# Test2     85   90      85
# Test3     90   85      90

# %%
grades.sort_values(by = 'Test1', axis = 1, ascending = False)
# Out:
#        Ahmad  Rashid  Ali
# Test1     80      75   70
# Test2     85      85   90
# Test3     90      90   85

# %%
grades.sort_values(by ='Test1', ascending = False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-52-cf55a2dc78bf> in <cell line: 1>()
# ----> 1 grades.sort_values(by ='Test1', ascending = False)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    6910
#    6911             by = by[0]
# -> 6912             k = self._get_label_or_level_values(by, axis=axis)
#    6913
#    6914             # need to rewrap column in Series to apply key function
#
# ...

# %%
grades.loc['Test1'].sort_values(ascending = False)
# Out:
# Ahmad     80
# Rashid    75
# Ali       70
# Name: Test1, dtype: int64

# %%
grades[ grades >= 80]
# Out:
#         Ali  Ahmad  Rashid
# Test1   NaN     80     NaN
# Test2  90.0     85    85.0
# Test3  85.0     90    90.0

# %%
grades[(grades >= 80) & (grades < 90)]
# Out:
#         Ali  Ahmad  Rashid
# Test1   NaN   80.0     NaN
# Test2   NaN   85.0    85.0
# Test3  85.0    NaN     NaN
